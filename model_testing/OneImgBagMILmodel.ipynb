# %% [markdown]
# # Imports

# %%
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import json
import torchvision.transforms.functional as TF
from PIL import Image, ImageDraw, ImageFilter, ImageEnhance
import albumentations as A
from albumentations.pytorch import ToTensorV2
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, Subset, WeightedRandomSampler
import torchvision
from torchvision import transforms, datasets, models
from torchvision.models import (resnet18, ResNet18_Weights, resnet50, ResNet50_Weights, resnet152, ResNet152_Weights,
                              efficientnet_b0, EfficientNet_B0_Weights,
                              vgg16, VGG16_Weights)
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             roc_auc_score, confusion_matrix, classification_report)
from sklearn.preprocessing import label_binarize
from sklearn.model_selection import train_test_split
import time
import random
import copy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
torch.manual_seed(42)
random.seed(42)
np.random.seed(42)
#torch.cuda.manual_seed_all(RANDOM_SEED)

# %% [markdown]
# # Configs

# %%
TRAIN_IMGS_PATH = '/content/drive/MyDrive/GBCUD/dataset/train'
TEST_IMGS_PATH = '/content/drive/MyDrive/GBCUD/dataset/test'
SAVE_MODEL_DIR = '/content/drive/MyDrive/GBCUD/'

# %%
RANDOM_SEED = 42
LABEL_MAPPING = {'0_normal': 0, '1_benign': 1, '2_malignant': 2}
CLASS_NAMES = list(LABEL_MAPPING.keys())

LEARNING_RATE = 1e-5
WEIGHT_DECAY = 1e-5
BATCH_SIZE = 1      # 1 bag
NUM_EPOCHS = 50
PATIENCE = 10
NUM_CLASSES = len(LABEL_MAPPING)
CLASS_WEIGHTS = [0.8, 0.6, 3.0] # Example weights

# FEATURE_DIM_L = 512
# ATTENTION_DIM_D = 256
# ATTENTION_HEADS_K = 1
DROPOUT_RATE = 0.5

IMG_RESIZE = (256, 256) # Initial resize size
IMG_CROP_SIZE = (224, 224) # Final input size to model

# Define normalization constants
IMAGENET_MEAN = [0.485, 0.456, 0.406]
IMAGENET_STD = [0.229, 0.224, 0.225]

# %% [markdown]
# # Helper functions

# %%
#plots training and validation loss and accuracy graphs
def plot_training_history(train_losses, train_acc, val_losses, val_acc):
    epochs_range = range(1, len(train_losses) + 1)

    plt.figure(figsize=(15, 5))

    # accuracy graph
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, train_acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.title('Model Accuracy over epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    # loss graph
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, train_losses, label='Training Loss')
    plt.plot(epochs_range, val_losses, label='Validation Loss')
    plt.title('Model Loss over epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

#compute and plot the confusion matrix
def plot_confusion_matrix(true_labels, predictions, class_names):
    cm = confusion_matrix(true_labels, predictions)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, cmap='Blues', fmt='d',
                xticklabels=class_names, yticklabels=class_names)
    plt.title('Confusion Matrix (Test Data)')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

# %% [markdown]
# # Preprocessing and Data augmentation

# %%
 # applies transforms to the entire image before patching
def get_train_transforms(resize_dim=IMG_RESIZE, crop_dim=IMG_CROP_SIZE):
  def crop_top_half(image, **kwargs):
      h, w = image.shape[:2]
      y_min = int(0.20 * h)
      y_max = int(0.90 * h)
      return image[y_min:y_max, :]

  return A.Compose([
      A.Resize(height=resize_dim[0], width=resize_dim[1]),
      A.Rotate(limit=10, p=0.5, border_mode=cv2.BORDER_CONSTANT, fill=0),
      A.RandomBrightnessContrast(brightness_limit=0.15, contrast_limit=0.15, p=0.5),
      A.ISONoise(intensity=(0.1, 0.4), p=0.3),
      # A.RandomShadow(p=0.3),
      A.Lambda(image=crop_top_half),
      # A.CenterCrop(height=crop_dim[0], width=crop_dim[1]),
      A.HorizontalFlip(p=0.5),
      A.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD),
      ToTensorV2()
  ])

def get_eval_transforms(img_dim=IMG_CROP_SIZE):
    return A.Compose([
        A.Resize(height=img_dim[0], width=img_dim[1]),
        A.CenterCrop(height=img_dim[0], width=img_dim[1]),
        A.Normalize(mean=IMAGENET_MEAN, std=IMAGENET_STD),
        ToTensorV2()
    ])

# %%
import matplotlib.pyplot as plt
import albumentations as A
from albumentations.pytorch import ToTensorV2
import cv2
from torchvision.transforms.functional import to_pil_image
import numpy as np


# Load and transform image
def visualize_transformed_image(image_path, transform):
    original_img = cv2.imread(image_path)
    original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)

    transformed = transform(image=original_img)
    transformed_img = transformed["image"]

    # De-normalize for visualization
    img_vis = transformed_img.clone()
    img_vis = img_vis * torch.tensor([0.229, 0.224, 0.225]).view(3,1,1)
    img_vis = img_vis + torch.tensor([0.485, 0.456, 0.406]).view(3,1,1)
    img_vis = torch.clamp(img_vis, 0, 1)

    return original_img, to_pil_image(img_vis)

# Example usage:
sample_paths = {
    "Normal": "/content/drive/MyDrive/GBCUD/dataset/train/0_normal/im00007.jpg",
    "Benign": "/content/drive/MyDrive/GBCUD/dataset/train/1_benign/im00001.jpg",
    "Malignant": "/content/drive/MyDrive/GBCUD/dataset/train/2_malignant/im00017.jpg"
}

transform = get_train_transforms()

fig, axes = plt.subplots(3, 2, figsize=(10, 12))

for idx, (label, img_path) in enumerate(sample_paths.items()):
    original, transformed = visualize_transformed_image(img_path, transform)

    axes[idx, 0].imshow(original)
    axes[idx, 0].set_title(f"{label} - Original")
    axes[idx, 0].axis("off")

    axes[idx, 1].imshow(transformed)
    axes[idx, 1].set_title(f"{label} - Transformed")
    axes[idx, 1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Dataset

# %%
import os
import numpy as np
from PIL import Image
from torch.utils.data import Dataset

class ImageBagDataset(Dataset):
    def __init__(self, image_dir, transform=None):
        """
        Args:
            image_dir (str): Root directory with subfolders for each class.
            transform (callable): Albumentations transform to apply to each image.
        """
        self.image_dir = image_dir
        self.transform = transform
        self.samples = []
        self.labels = []

        class_folders = sorted(os.listdir(image_dir))
        for folder_name in class_folders:
            label = int(folder_name.split('_')[0])
            folder_path = os.path.join(image_dir, folder_name)
            for img_name in os.listdir(folder_path):
                img_path = os.path.join(folder_path, img_name)
                self.samples.append(img_path)
                self.labels.append(label)

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path = self.samples[idx]
        label = self.labels[idx]
        image_name = os.path.basename(img_path)

        image = np.array(Image.open(img_path).convert("RGB"))

        if self.transform:
            image = self.transform(image=image)["image"]

        return image, label, image_name

# %% [markdown]
# # Model build

# %%
class AttentionMILModel(nn.Module):
    def __init__(self, num_classes=3, backbone_name='resnet18', pretrained=True,
                 feature_dim=512, attention_dim=128, attention_heads=1, dropout=0.5):
        super().__init__()
        self.L = feature_dim  # 512 node fully connected layer
        self.D = attention_dim  # 128 node attention layer
        self.K = attention_heads
        self.num_classes = num_classes

        # backbone
        self.feature_extractor, backbone_out_dim = self._get_backbone(backbone_name, pretrained)

        # Adaptive pooling and feature embedding
        self.pool = nn.AdaptiveAvgPool2d((1, 1))
        self.feature_embedder = nn.Sequential(
            nn.Linear(backbone_out_dim, self.L),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(self.L, self.L),
            nn.ReLU(),
            nn.Dropout(dropout)
        )

        self.attention = nn.Sequential(
            nn.Linear(self.L, self.D),
            nn.Tanh(),
            nn.Linear(self.D, self.K)
        )

        self.classifier = nn.Linear(self.L * self.K, self.num_classes)

    def _get_backbone(self, name, pretrained):
        weights = 'DEFAULT' if pretrained else None

        if name == "resnet18":
            model = resnet18(weights=weights)
            return nn.Sequential(*list(model.children())[:-2]), 512
        elif name == "resnet50":
            model = resnet50(weights=weights)
            return nn.Sequential(*list(model.children())[:-2]), 2048
        elif name == "resnet152":
            model = resnet152(weights=weights)
            return nn.Sequential(*list(model.children())[:-2]), 2048
        elif name == "efficientnet_b0":
            model = efficientnet_b0(weights=weights)
            return model.features, 1280
        elif name == "vgg16":
            model = vgg16(weights=weights)
            return nn.Sequential(*list(model.features.children())[:-1]), 512
        else:
            raise ValueError(f"Error with backbone {name}")

    def forward(self, x):
        # x: [1, C, H, W]
        features = self.feature_extractor(x)
        features = self.pool(features).view(1, -1)
        embedded = self.feature_embedder(features)

        A = self.attention(embedded)
        A = F.softmax(A, dim=0)
        M = A * embedded

        logits = self.classifier(M.view(1, -1))
        probs = F.softmax(logits, dim=1)
        return logits, probs, A

    def calculate_objective(self, x_batch, y_batch, criterion):
        logits, _, _ = self.forward(x_batch)
        return criterion(logits, y_batch)

    def calculate_prediction_accuracy(self, x_batch, y_batch):
        logits, _, _ = self.forward(x_batch)
        preds = torch.argmax(logits, dim=1)
        correct = preds.eq(y_batch).sum().item()
        total = y_batch.size(0)
        return preds, correct / total, correct, total

    def get_attention_map(self, bag_tensor):
        self.eval()
        with torch.no_grad():
            if image_tensor.ndim != 4:
                raise ValueError(f"Wrong input shape: {image_tensor.shape}")
            image_tensor = image_tensor.to(next(self.parameters()).device)

            features = self.feature_extractor(image_tensor)
            features = self.pool(features).view(1, -1)
            embedded = self.feature_embedder(features)
            A = self.attention(embedded)
            A = F.softmax(A, dim=0)
            return A.squeeze().cpu().numpy()

# %%
#vanilla attention
model = AttentionMILModel(num_classes=3, backbone_name='resnet18')
print(model)
# Out:
# AttentionMILModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (feature_embedder): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#   )
#   (attention): Sequential(
#     (0): Linear(in_features=512, out_features=128, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
#   (classifier): Linear(in_features=512, out_features=3, bias=True)
# )

# %%
dummy_input = torch.randn(1, 3, 224, 224)
logits, probs, att = model(dummy_input)
print(model)
# Out:
# AttentionMILModel(
#   (feature_extractor): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (pool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (feature_embedder): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.5, inplace=False)
#   )
#   (attention): Sequential(
#     (0): Linear(in_features=512, out_features=128, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=128, out_features=1, bias=True)
#   )
#   (classifier): Linear(in_features=512, out_features=3, bias=True)
# )

# %% [markdown]
# # Train and Evaluate

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer,
                num_epochs, device, save_dir, model_name, patience=PATIENCE):

  os.makedirs(save_dir, exist_ok=True)
  save_path = os.path.join(save_dir, model_name)

  best_val_loss = float('inf')
  epochs_no_improve = 0
  history = {'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': []}


  model.to(device)
  print(f"Start Training model")

  for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    train_correct = 0
    train_total = 0

    for bags, labels, _ in train_loader:
      bags = bags[0].unsqueeze(0).to(device)
      labels = labels.to(device)

      optimizer.zero_grad()
      logits, probs, _ = model(bags)
      loss = criterion(logits, labels)
      loss.backward()
      optimizer.step()

      running_loss += loss.item()
      predictions = torch.argmax(probs, dim=1)
      train_correct += (predictions == labels).sum().item()
      train_total += labels.size(0)

    epoch_train_loss = running_loss / train_total
    epoch_train_acc = train_correct / train_total
    history['train_loss'].append(epoch_train_loss)
    history['train_acc'].append(epoch_train_acc)

    # validation
    val_metrics, _, _ = evaluate_model(model, val_loader, criterion, device)
    epoch_val_loss = val_metrics['loss']
    epoch_val_acc = val_metrics['accuracy']
    history['val_loss'].append(epoch_val_loss)
    history['val_acc'].append(epoch_val_acc)

    print(f"Epoch {epoch+1}/{num_epochs} | "
          f"Train Loss: {epoch_train_loss:.4f}, Acc: {epoch_train_acc:.4f} | "
          f"Val Loss: {epoch_val_loss:.4f}, Acc: {epoch_val_acc:.4f}")

    # early stopping
    if epoch_val_loss < best_val_loss:
      best_val_loss = epoch_val_loss
      epochs_no_improve = 0
      torch.save(model.state_dict(), save_path)
      print(f"Model saved to {save_path}")
    else:
      epochs_no_improve += 1
      print(f"Validation loss did not improve for {epochs_no_improve} epochs :(")
      if epochs_no_improve >= patience:
        print(f"Early stopping at epoch {epoch+1}")
        break

  print("\nTraining donee.")

  model.load_state_dict(torch.load(save_path))
  print("Loaded model weights.")

  return model, history

# %%
def evaluate_model(model, dataloader, criterion, device):
    model.eval()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0

    all_predictions = []
    all_true_labels = []
    all_probs = []

    with torch.no_grad():
        for bags, labels, _ in dataloader:
            image = bags[0].unsqueeze(0).to(device)
            labels = labels.to(device)

            outputs, probabilities, _ = model(image)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            predictions = torch.argmax(probabilities, dim=1)
            all_predictions.extend(predictions.cpu().numpy())
            all_true_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

            total_correct += (predictions == labels).sum().item()
            total_samples += labels.size(0)

    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples

    precision = precision_score(all_true_labels, all_predictions, average='macro', zero_division=0)
    recall = recall_score(all_true_labels, all_predictions, average='macro', zero_division=0)
    f1 = f1_score(all_true_labels, all_predictions, average='macro', zero_division=0)
    auc = roc_auc_score(all_true_labels, all_probs, average='macro', multi_class='ovr')

    metrics = {
        'loss': avg_loss,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'auc': auc
    }
    return metrics, all_true_labels, all_predictions

# %% [markdown]
# # Experiments

# %%
BACKBONE_NAME = "resnet18"
PRETRAINED = "true"

# %%
if __name__ == "__main__":
    print(f"Using device: {device}")

    train_transforms = get_train_transforms(resize_dim=IMG_RESIZE, crop_dim=IMG_CROP_SIZE)
    eval_transforms = get_eval_transforms(img_dim=IMG_CROP_SIZE)

    print("Loading the datasets")

    full_train_dataset = ImageBagDataset(
        image_dir=TRAIN_IMGS_PATH,
        transform=train_transforms
    )

    test_dataset = ImageBagDataset(
    image_dir=TEST_IMGS_PATH,
    transform=eval_transforms
    )

    print(f"Train dataset: {len(full_train_dataset)} images.")
    print(f"Test dataset: {len(test_dataset)} images.")

    # Train/Validation Split
    print("Splitting train data")
    targets = full_train_dataset.labels

    train_idx, val_idx = train_test_split(
        np.arange(len(targets)),
        test_size=0.2, # 20% for validation
        stratify=targets,
        random_state=RANDOM_SEED
    )

    train_subset = Subset(full_train_dataset, train_idx)
    val_subset = Subset(full_train_dataset, val_idx)

    # Weighted sampler for the training subset
    train_targets = np.array(targets)[train_idx]
    class_counts = np.bincount(train_targets, minlength=NUM_CLASSES)

    weights = 1.0 / class_counts #what if a class has no samples in the split

    sample_weights = np.array([weights[label] for label in train_targets])
    sampler = WeightedRandomSampler(sample_weights, len(sample_weights), replacement=True)

    print(f"Training subset size: {len(train_subset)}")
    print(f"Validation subset size: {len(val_subset)}")


    print("DataLoaders")
    num_workers = 2

    train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, sampler=sampler, num_workers=num_workers, pin_memory=True)
    val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True)

    # creating model instance
    print(f"Model with {BACKBONE_NAME} backbone")
    model = AttentionMILModel(
        num_classes=NUM_CLASSES,
        backbone_name=BACKBONE_NAME,
        pretrained=PRETRAINED,
        dropout=DROPOUT_RATE).to(device)


    class_weights_tensor = torch.tensor(CLASS_WEIGHTS, device=device, dtype=torch.float)
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
    print(f"Using CrossEntropyLoss with the weights: {CLASS_WEIGHTS}")


    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
    # scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.1)

    # train model
    trained_model, history = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        criterion=criterion,
        optimizer=optimizer,
        num_epochs=NUM_EPOCHS,
        device=device,
        save_dir=SAVE_MODEL_DIR,
        model_name='sbam1.pth',
        patience=PATIENCE
    )

    # Evaluat on Test Set
    print("\nEvaluating on test set")
    trained_model.to(device)
    test_metrics, all_labels, all_preds = evaluate_model(trained_model, test_loader, criterion, device)
    cmatrix = confusion_matrix(all_labels, all_preds)

    print("\nTest Set Evaluation Metrics")
    print(f"Loss: {test_metrics['loss']:.4f}")
    print(f"Accuracy: {test_metrics['accuracy']:.4f}")
    print(f"Precision: {test_metrics['precision']:.4f}")
    print(f"Recall: {test_metrics['recall']:.4f}")
    print(f"F1 Score: {test_metrics['f1']:.4f}")
    print("Confusion Matrix:")
    print(cmatrix)
    print("")

    print("\nEvaluation per class")
    print(classification_report(all_labels, all_preds, target_names=["Normal", "Benign", "Malignant"]))


    # --- Plotting ---
    print("\nPlotting results")
    plot_training_history(history['train_loss'], history['train_acc'],
                          history['val_loss'], history['val_acc'])

    #Confusion matrix
    plot_confusion_matrix(all_labels, all_preds, class_names=CLASS_NAMES)

    print("\nDONEEEEE.")
# Out:
# Using device: cuda
# Loading the datasets
# Train dataset: 1133 images.
# Test dataset: 122 images.
# Splitting train data
# Training subset size: 906
# Validation subset size: 227
# DataLoaders
# Model with resnet18 backbone
# Using CrossEntropyLoss with the weights: [0.8, 0.6, 3.0]
# Start Training model
# Epoch 1/50 | Train Loss: 1.1129, Acc: 0.3344 | Val Loss: 1.0934, Acc: 0.3612
# Model saved to /content/drive/MyDrive/GBCUD/sbam1.pth
# Epoch 2/50 | Train Loss: 1.1058, Acc: 0.3278 | Val Loss: 1.1077, Acc: 0.2555
# Validation loss did not improve for 1 epochs :(
# Epoch 3/50 | Train Loss: 1.1065, Acc: 0.3267 | Val Loss: 1.1044, Acc: 0.2952
# Validation loss did not improve for 2 epochs :(
# Epoch 4/50 | Train Loss: 1.1018, Acc: 0.3521 | Val Loss: 1.1085, Acc: 0.2907
# Validation loss did not improve for 3 epochs :(
# Epoch 5/50 | Train Loss: 1.0952, Acc: 0.3819 | Val Loss: 1.1093, Acc: 0.2996
# Validation loss did not improve for 4 epochs :(
# Epoch 6/50 | Train Loss: 1.0671, Acc: 0.4525 | Val Loss: 1.1576, Acc: 0.1366
# Validation loss did not improve for 5 epochs :(
# Epoch 7/50 | Train Loss: 0.9807, Acc: 0.5541 | Val Loss: 1.3941, Acc: 0.1013
# Validation loss did not improve for 6 epochs :(
# Epoch 8/50 | Train Loss: 0.8510, Acc: 0.6082 | Val Loss: 1.6268, Acc: 0.0925
# Validation loss did not improve for 7 epochs :(
# Epoch 9/50 | Train Loss: 0.7205, Acc: 0.6645 | Val Loss: 1.6212, Acc: 0.1674
# Validation loss did not improve for 8 epochs :(
# Epoch 10/50 | Train Loss: 0.6559, Acc: 0.6711 | Val Loss: 1.6206, Acc: 0.2159
# Validation loss did not improve for 9 epochs :(
# Epoch 11/50 | Train Loss: 0.5627, Acc: 0.7075 | Val Loss: 2.0896, Acc: 0.1454
# Validation loss did not improve for 10 epochs :(
# Early stopping at epoch 11
#
# Training donee.
# Loaded model weights.
#
# Evaluating on test set
#
# Test Set Evaluation Metrics
# Loss: 1.1262
# Accuracy: 0.2459
# Precision: 0.2479
# Recall: 0.3186
# F1 Score: 0.1420
# Confusion Matrix:
# [[29  1  1]
#  [48  1  0]
#  [42  0  0]]
#
#
# Evaluation per class
#               precision    recall  f1-score   support
#
#       Normal       0.24      0.94      0.39        31
#       Benign       0.50      0.02      0.04        49
#    Malignant       0.00      0.00      0.00        42
#
#     accuracy                           0.25       122
#    macro avg       0.25      0.32      0.14       122
# weighted avg       0.26      0.25      0.11       122
#
#
# Plotting results
# DONEEEEE.

# %%
BACKBONE_NAME = "resnet50"
PRETRAINED = "true"

# %%
if __name__ == "__main__":
    print(f"Using device: {device}")

    train_transforms = get_train_transforms(resize_dim=IMG_RESIZE, crop_dim=IMG_CROP_SIZE)
    eval_transforms = get_eval_transforms(img_dim=IMG_CROP_SIZE)

    print("Loading the datasets")

    full_train_dataset = ImageBagDataset(
        image_dir=TRAIN_IMGS_PATH,
        transform=train_transforms
    )

    test_dataset = ImageBagDataset(
    image_dir=TEST_IMGS_PATH,
    transform=eval_transforms
    )

    print(f"Train dataset: {len(full_train_dataset)} images.")
    print(f"Test dataset: {len(test_dataset)} images.")

    # Train/Validation Split
    print("Splitting train data")
    targets = full_train_dataset.labels

    train_idx, val_idx = train_test_split(
        np.arange(len(targets)),
        test_size=0.2, # 20% for validation
        stratify=targets,
        random_state=RANDOM_SEED
    )

    train_subset = Subset(full_train_dataset, train_idx)
    val_subset = Subset(full_train_dataset, val_idx)

    # Weighted sampler for the training subset
    train_targets = np.array(targets)[train_idx]
    class_counts = np.bincount(train_targets, minlength=NUM_CLASSES)

    weights = 1.0 / class_counts #what if a class has no samples in the split

    sample_weights = np.array([weights[label] for label in train_targets])
    sampler = WeightedRandomSampler(sample_weights, len(sample_weights), replacement=True)

    print(f"Training subset size: {len(train_subset)}")
    print(f"Validation subset size: {len(val_subset)}")


    print("DataLoaders")
    num_workers = 2

    train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, sampler=sampler, num_workers=num_workers, pin_memory=True)
    val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True)

    # creating model instance
    print(f"Model with {BACKBONE_NAME} backbone")
    model = AttentionMILModel(
        num_classes=NUM_CLASSES,
        backbone_name=BACKBONE_NAME,
        pretrained=PRETRAINED,
        dropout=DROPOUT_RATE).to(device)


    class_weights_tensor = torch.tensor(CLASS_WEIGHTS, device=device, dtype=torch.float)
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
    print(f"Using CrossEntropyLoss with the weights: {CLASS_WEIGHTS}")


    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
    # scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.1)

    # train model
    trained_model, history = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        criterion=criterion,
        optimizer=optimizer,
        num_epochs=NUM_EPOCHS,
        device=device,
        save_dir=SAVE_MODEL_DIR,
        model_name='sbam2.pth',
        patience=PATIENCE
    )

    # Evaluat on Test Set
    print("\nEvaluating on test set")
    trained_model.to(device)
    test_metrics, all_labels, all_preds = evaluate_model(trained_model, test_loader, criterion, device)
    cmatrix = confusion_matrix(all_labels, all_preds)

    print("\nTest Set Evaluation Metrics")
    print(f"Loss: {test_metrics['loss']:.4f}")
    print(f"Accuracy: {test_metrics['accuracy']:.4f}")
    print(f"Precision: {test_metrics['precision']:.4f}")
    print(f"Recall: {test_metrics['recall']:.4f}")
    print(f"F1 Score: {test_metrics['f1']:.4f}")
    print("Confusion Matrix:")
    print(cmatrix)
    print("")

    print("\nEvaluation per class")
    print(classification_report(all_labels, all_preds, target_names=["Normal", "Benign", "Malignant"]))


    # --- Plotting ---
    print("\nPlotting results")
    plot_training_history(history['train_loss'], history['train_acc'],
                          history['val_loss'], history['val_acc'])

    #Confusion matrix
    plot_confusion_matrix(all_labels, all_preds, class_names=CLASS_NAMES)

    print("\nDONEEEEE.")
# Out:
# Using device: cuda
# Loading the datasets
# Train dataset: 1133 images.
# Test dataset: 122 images.
# Splitting train data
# Training subset size: 906
# Validation subset size: 227
# DataLoaders
# Model with resnet50 backbone
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 200MB/s]
# Using CrossEntropyLoss with the weights: [0.8, 0.6, 3.0]
# Start Training model
# Epoch 1/50 | Train Loss: 1.0990, Acc: 0.3333 | Val Loss: 1.0965, Acc: 0.3744
# Model saved to /content/drive/MyDrive/GBCUD/sbam2.pth
# Epoch 2/50 | Train Loss: 1.0932, Acc: 0.3764 | Val Loss: 1.0931, Acc: 0.4493
# Model saved to /content/drive/MyDrive/GBCUD/sbam2.pth
# Epoch 3/50 | Train Loss: 1.0922, Acc: 0.3631 | Val Loss: 1.0905, Acc: 0.4493
# Model saved to /content/drive/MyDrive/GBCUD/sbam2.pth
# Epoch
# Epoch 27/50 | Train Loss: 0.1125, Acc: 0.9592 | Val Loss: 0.6863, Acc: 0.7445
# Validation loss did not improve for 8 epochs :(
# Epoch 28/50 | Train Loss: 0.0880, Acc: 0.9647 | Val Loss: 0.8720, Acc: 0.7093
# Validation loss did not improve for 9 epochs :(
# Epoch 29/50 | Train Loss: 0.0742, Acc: 0.9680 | Val Loss: 0.7177, Acc: 0.7401
# Validation loss did not improve for 10 epochs :(
# Early stopping at epoch 29
#
# Training donee.
# Loaded model weights.
#
# Evaluating on test set
#
# Test Set Evaluation Metrics
# Loss: 1.1158
# Accuracy: 0.5246
# Precision: 0.5410
# Recall: 0.5296
# F1 Score: 0.4786
# Confusion Matrix:
# [[23  8  0]
#  [ 7 38  4]
#  [ 1 38  3]]
#
#
# Evaluation per class
#               precision    recall  f1-score   support
#
#       Normal       0.74      0.74      0.74        31
#       Benign       0.45      0.78      0.57        49
#    Malignant       0.43      0.07      0.12        42
#
#     accuracy                           0.52       122
#    macro avg       0.54      0.53      0.48       122
# weighted avg       0.52      0.52      0.46       122
#
#
# Plotting results
# DONEEEEE.

# %%
BACKBONE_NAME = "resnet152"
PRETRAINED = "true"

# %%
if __name__ == "__main__":
    print(f"Using device: {device}")

    train_transforms = get_train_transforms(resize_dim=IMG_RESIZE, crop_dim=IMG_CROP_SIZE)
    eval_transforms = get_eval_transforms(img_dim=IMG_CROP_SIZE)

    print("Loading the datasets")

    full_train_dataset = ImageBagDataset(
        image_dir=TRAIN_IMGS_PATH,
        transform=train_transforms
    )

    test_dataset = ImageBagDataset(
    image_dir=TEST_IMGS_PATH,
    transform=eval_transforms
    )

    print(f"Train dataset: {len(full_train_dataset)} images.")
    print(f"Test dataset: {len(test_dataset)} images.")

    # Train/Validation Split
    print("Splitting train data")
    targets = full_train_dataset.labels

    train_idx, val_idx = train_test_split(
        np.arange(len(targets)),
        test_size=0.2, # 20% for validation
        stratify=targets,
        random_state=RANDOM_SEED
    )

    train_subset = Subset(full_train_dataset, train_idx)
    val_subset = Subset(full_train_dataset, val_idx)

    # Weighted sampler for the training subset
    train_targets = np.array(targets)[train_idx]
    class_counts = np.bincount(train_targets, minlength=NUM_CLASSES)

    weights = 1.0 / class_counts #what if a class has no samples in the split

    sample_weights = np.array([weights[label] for label in train_targets])
    sampler = WeightedRandomSampler(sample_weights, len(sample_weights), replacement=True)

    print(f"Training subset size: {len(train_subset)}")
    print(f"Validation subset size: {len(val_subset)}")


    print("DataLoaders")
    num_workers = 2

    train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, sampler=sampler, num_workers=num_workers, pin_memory=True)
    val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True)

    # creating model instance
    print(f"Model with {BACKBONE_NAME} backbone")
    model = AttentionMILModel(
        num_classes=NUM_CLASSES,
        backbone_name=BACKBONE_NAME,
        pretrained=PRETRAINED,
        dropout=DROPOUT_RATE).to(device)


    class_weights_tensor = torch.tensor(CLASS_WEIGHTS, device=device, dtype=torch.float)
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
    print(f"Using CrossEntropyLoss with the weights: {CLASS_WEIGHTS}")


    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
    # scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.1)

    # train model
    trained_model, history = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        criterion=criterion,
        optimizer=optimizer,
        num_epochs=NUM_EPOCHS,
        device=device,
        save_dir=SAVE_MODEL_DIR,
        model_name='sbam3.pth',
        patience=PATIENCE
    )

    # Evaluat on Test Set
    print("\nEvaluating on test set")
    trained_model.to(device)
    test_metrics, all_labels, all_preds = evaluate_model(trained_model, test_loader, criterion, device)
    cmatrix = confusion_matrix(all_labels, all_preds)

    print("\nTest Set Evaluation Metrics")
    print(f"Loss: {test_metrics['loss']:.4f}")
    print(f"Accuracy: {test_metrics['accuracy']:.4f}")
    print(f"Precision: {test_metrics['precision']:.4f}")
    print(f"Recall: {test_metrics['recall']:.4f}")
    print(f"F1 Score: {test_metrics['f1']:.4f}")
    print("Confusion Matrix:")
    print(cmatrix)
    print("")

    print("\nEvaluation per class")
    print(classification_report(all_labels, all_preds, target_names=["Normal", "Benign", "Malignant"]))


    # --- Plotting ---
    print("\nPlotting results")
    plot_training_history(history['train_loss'], history['train_acc'],
                          history['val_loss'], history['val_acc'])

    #Confusion matrix
    plot_confusion_matrix(all_labels, all_preds, class_names=CLASS_NAMES)

    print("\nDONEEEEE.")
# Out:
# Using device: cuda
# Loading the datasets
# Train dataset: 1133 images.
# Test dataset: 122 images.
# Splitting train data
# Training subset size: 906
# Validation subset size: 227
# DataLoaders
# Model with resnet152 backbone
# Downloading: "https://download.pytorch.org/models/resnet152-f82ba261.pth" to /root/.cache/torch/hub/checkpoints/resnet152-f82ba261.pth
# 100%|██████████| 230M/230M [00:01<00:00, 216MB/s]
# Using CrossEntropyLoss with the weights: [0.8, 0.6, 3.0]
# Start Training model
# Epoch 1/50 | Train Loss: 1.0994, Acc: 0.3289 | Val Loss: 1.1072, Acc: 0.3260
# Model saved to /content/drive/MyDrive/GBCUD/sbam3.pth
# Epoch 2/50 | Train Loss: 1.0976, Acc: 0.3477 | Val Loss: 1.1424, Acc: 0.2379
# Validation loss did not improve for 1 epochs :(
# Epoch 3/50 | Train Loss: 1.0907, Acc: 0.3764 | Val Loss: 1.1448, Acc: 0.2070
# Validation loss did not improve for 2 epochs :(
# Epoch 4/50 | Train Loss: 1.0072, Acc: 0.4978 | Val Loss: 0.9992, Acc: 0.5815
# Model saved to /content/drive/MyDrive/GBCUD/sbam3.pth
# Epoch 5/50 | Train Loss: 0.6931, Acc: 0.7163 | Val Loss: 0.8714, Acc: 0.5947
# Model saved to /content/drive/MyDrive/GBCUD/sbam3.pth
# Epoch 6/50 | Train Loss: 0.5438, Acc: 0.8068 | Val Loss: 0.9768, Acc: 0.4978
# Validation loss did not improve for 1 epochs :(
# Epoch 7/50 | Train Loss: 0.4113, Acc: 0.8521 | Val Loss: 1.6771, Acc: 0.4097
# Validation loss did not improve for 2 epochs :(
# Epoch 8/50 | Train Loss: 0.3184, Acc: 0.8929 | Val Loss: 1.3941, Acc: 0.5419
# Validation loss did not improve for 3 epochs :(
# Epoch 9/50 | Train Loss: 0.2555, Acc: 0.9172 | Val Loss: 1.8079, Acc: 0.4670
# Validation loss did not improve for 4 epochs :(
# Epoch 10/50 | Train Loss: 0.2311, Acc: 0.9161 | Val Loss: 1.1013, Acc: 0.5242
# Validation loss did not improve for 5 epochs :(
# Epoch 11/50 | Train Loss: 0.1547, Acc: 0.9525 | Val Loss: 1.2660, Acc: 0.5374
# Validation loss did not improve for 6 epochs :(
# Epoch 12/50 | Train Loss: 0.1734, Acc: 0.9459 | Val Loss: 2.0426, Acc: 0.4493
# Validation loss did not improve for 7 epochs :(
# Epoch 13/50 | Train Loss: 0.1041, Acc: 0.9680 | Val Loss: 3.2572, Acc: 0.5242
# Validation loss did not improve for 8 epochs :(
# Epoch 14/50 | Train Loss: 0.1388, Acc: 0.9570 | Val Loss: 2.6708, Acc: 0.5419
# Validation loss did not improve for 9 epochs :(
# Epoch 15/50 | Train Loss: 0.1058, Acc: 0.9658 | Val Loss: 2.0611, Acc: 0.5374
# Validation loss did not improve for 10 epochs :(
# Early stopping at epoch 15
#
# Training donee.
# Loaded model weights.
#
# Evaluating on test set
#
# Test Set Evaluation Metrics
# Loss: 0.8748
# Accuracy: 0.5082
# Precision: 0.5674
# Recall: 0.5382
# F1 Score: 0.4729
# Confusion Matrix:
# [[18  4  9]
#  [ 3  4 42]
#  [ 1  1 40]]
#
#
# Evaluation per class
#               precision    recall  f1-score   support
#
#       Normal       0.82      0.58      0.68        31
#       Benign       0.44      0.08      0.14        49
#    Malignant       0.44      0.95      0.60        42
#
#     accuracy                           0.51       122
#    macro avg       0.57      0.54      0.47       122
# weighted avg       0.54      0.51      0.44       122
#
#
# Plotting results
# DONEEEEE.

# %%
BACKBONE_NAME = "efficientnet_b0"
PRETRAINED = "true"

# %%
if __name__ == "__main__":
    print(f"Using device: {device}")

    train_transforms = get_train_transforms(resize_dim=IMG_RESIZE, crop_dim=IMG_CROP_SIZE)
    eval_transforms = get_eval_transforms(img_dim=IMG_CROP_SIZE)

    print("Loading the datasets")

    full_train_dataset = ImageBagDataset(
        image_dir=TRAIN_IMGS_PATH,
        transform=train_transforms
    )

    test_dataset = ImageBagDataset(
    image_dir=TEST_IMGS_PATH,
    transform=eval_transforms
    )

    print(f"Train dataset: {len(full_train_dataset)} images.")
    print(f"Test dataset: {len(test_dataset)} images.")

    # Train/Validation Split
    print("Splitting train data")
    targets = full_train_dataset.labels

    train_idx, val_idx = train_test_split(
        np.arange(len(targets)),
        test_size=0.2, # 20% for validation
        stratify=targets,
        random_state=RANDOM_SEED
    )

    train_subset = Subset(full_train_dataset, train_idx)
    val_subset = Subset(full_train_dataset, val_idx)

    # Weighted sampler for the training subset
    train_targets = np.array(targets)[train_idx]
    class_counts = np.bincount(train_targets, minlength=NUM_CLASSES)

    weights = 1.0 / class_counts #what if a class has no samples in the split

    sample_weights = np.array([weights[label] for label in train_targets])
    sampler = WeightedRandomSampler(sample_weights, len(sample_weights), replacement=True)

    print(f"Training subset size: {len(train_subset)}")
    print(f"Validation subset size: {len(val_subset)}")


    print("DataLoaders")
    num_workers = 2

    train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, sampler=sampler, num_workers=num_workers, pin_memory=True)
    val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True)

    # creating model instance
    print(f"Model with {BACKBONE_NAME} backbone")
    model = AttentionMILModel(
        num_classes=NUM_CLASSES,
        backbone_name=BACKBONE_NAME,
        pretrained=PRETRAINED,
        dropout=DROPOUT_RATE).to(device)


    class_weights_tensor = torch.tensor(CLASS_WEIGHTS, device=device, dtype=torch.float)
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
    print(f"Using CrossEntropyLoss with the weights: {CLASS_WEIGHTS}")


    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
    # scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.1)

    # train model
    trained_model, history = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        criterion=criterion,
        optimizer=optimizer,
        num_epochs=NUM_EPOCHS,
        device=device,
        save_dir=SAVE_MODEL_DIR,
        model_name='sbam4.pth',
        patience=PATIENCE
    )

    # Evaluat on Test Set
    print("\nEvaluating on test set")
    trained_model.to(device)
    test_metrics, all_labels, all_preds = evaluate_model(trained_model, test_loader, criterion, device)
    cmatrix = confusion_matrix(all_labels, all_preds)

    print("\nTest Set Evaluation Metrics")
    print(f"Loss: {test_metrics['loss']:.4f}")
    print(f"Accuracy: {test_metrics['accuracy']:.4f}")
    print(f"Precision: {test_metrics['precision']:.4f}")
    print(f"Recall: {test_metrics['recall']:.4f}")
    print(f"F1 Score: {test_metrics['f1']:.4f}")
    print("Confusion Matrix:")
    print(cmatrix)
    print("")

    print("\nEvaluation per class")
    print(classification_report(all_labels, all_preds, target_names=["Normal", "Benign", "Malignant"]))


    # --- Plotting ---
    print("\nPlotting results")
    plot_training_history(history['train_loss'], history['train_acc'],
                          history['val_loss'], history['val_acc'])

    #Confusion matrix
    plot_confusion_matrix(all_labels, all_preds, class_names=CLASS_NAMES)

    print("\nDONEEEEE.")
# Out:
# Using device: cuda
# Loading the datasets
# Train dataset: 1133 images.
# Test dataset: 122 images.
# Splitting train data
# Training subset size: 906
# Validation subset size: 227
# DataLoaders
# Model with efficientnet_b0 backbone
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 134MB/s]
# Using CrossEntropyLoss with the weights: [0.8, 0.6, 3.0]
# Start Training model
# Epoch 1/50 | Train Loss: 1.1018, Acc: 0.3068 | Val Loss: 1.1019, Acc: 0.2511
# Model saved to /content/drive/MyDrive/GBCUD/sbam4.pth
# Epoch 2/50 | Train Loss: 1.0999, Acc: 0.3477 | Val Loss: 1.1027, Acc: 0.2247
# Validation loss did not improve for 1 epochs :(
# Epoch 3/50 | Train Loss: 1.0947, Acc: 0.3720 | Val Loss: 1.1015, Acc: 0.3304
# Model saved to /content/drive/MyDrive/GBCUD/sbam4.pth
# Epoch 4/50 | Train Loss: 1.0954, Acc: 0.3764 | Val Loss: 1.1033, Acc: 0.2335
# Validation loss did not improve for 1 epochs :(
# Epoch 5/50 | Train Loss: 1.0909, Acc: 0.3874 | Val Loss: 1.1015, Acc: 0.2379
# Validation loss did not improve for 2 epochs :(
# Epoch 6/50 | Train Loss: 1.0722, Acc: 0.4581 | Val Loss: 1.1040, Acc: 0.2423
# Validation loss did not improve for 3 epochs :(
# Epoch 7/50 | Train Loss: 1.0028, Acc: 0.5574 | Val Loss: 1.1188, Acc: 0.2907
# Validation loss did not improve for 4 epochs :(
# Epoch 8/50 | Train Loss: 0.8285, Acc: 0.6402 | Val Loss: 0.9944, Acc: 0.4714
# Model saved to /content/drive/MyDrive/GBCUD/sbam4.pth
# Epoch 9/50 | Train Loss: 0.6956, Acc: 0.6898 | Val Loss: 1.1040, Acc: 0.4273
# Validation loss did not improve for 1 epochs :(
# Epoch 10/50 | Train Loss: 0.6916, Acc: 0.6556 | Val Loss: 1.1364, Acc: 0.3877
# Validation loss did not improve for 2 epochs :(
# Epoch 11/50 | Train Loss: 0.6023, Acc: 0.7329 | Val Loss: 1.1805, Acc: 0.4009
# Validation loss did not improve for 3 epochs :(
# Epoch 12/50 | Train Loss: 0.5796, Acc: 0.7583 | Val Loss: 1.1923, Acc: 0.4229
# Validation loss did not improve for 4 epochs :(
# Epoch 13/50 | Train Loss: 0.5455, Acc: 0.7550 | Val Loss: 1.1097, Acc: 0.4846
# Validation loss did not improve for 5 epochs :(
# Epoch 14/50 | Train Loss: 0.5111, Acc: 0.7759 | Val Loss: 1.0845, Acc: 0.5154
# Validation loss did not improve for 6 epochs :(
# Epoch 15/50 | Train Loss: 0.4813, Acc: 0.8091 | Val Loss: 1.1199, Acc: 0.4714
# Validation loss did not improve for 7 epochs :(
# Epoch 16/50 | Train Loss: 0.4495, Acc: 0.8057 | Val Loss: 1.1043, Acc: 0.5022
# Validation loss did not improve for 8 epochs :(
# Epoch 17/50 | Train Loss: 0.4248, Acc: 0.8355 | Val Loss: 1.1279, Acc: 0.4802
# Validation loss did not improve for 9 epochs :(
# Epoch 18/50 | Train Loss: 0.3995, Acc: 0.8466 | Val Loss: 1.0289, Acc: 0.4890
# Validation loss did not improve for 10 epochs :(
# Early stopping at epoch 18
#
# Training donee.
# Loaded model weights.
#
# Evaluating on test set
#
# Test Set Evaluation Metrics
# Loss: 0.9478
# Accuracy: 0.5328
# Precision: 0.6392
# Recall: 0.5490
# F1 Score: 0.4980
# Confusion Matrix:
# [[15  4 12]
#  [ 4  8 37]
#  [ 0  0 42]]
#
#
# Evaluation per class
#               precision    recall  f1-score   support
#
#       Normal       0.79      0.48      0.60        31
#       Benign       0.67      0.16      0.26        49
#    Malignant       0.46      1.00      0.63        42
#
#     accuracy                           0.53       122
#    macro avg       0.64      0.55      0.50       122
# weighted avg       0.63      0.53      0.48       122
#
#
# Plotting results
# DONEEEEE.

# %%
BACKBONE_NAME = "vgg16"
PRETRAINED = "true"

# %%
if __name__ == "__main__":
    print(f"Using device: {device}")

    train_transforms = get_train_transforms(resize_dim=IMG_RESIZE, crop_dim=IMG_CROP_SIZE)
    eval_transforms = get_eval_transforms(img_dim=IMG_CROP_SIZE)

    print("Loading the datasets")

    full_train_dataset = ImageBagDataset(
        image_dir=TRAIN_IMGS_PATH,
        transform=train_transforms
    )

    test_dataset = ImageBagDataset(
    image_dir=TEST_IMGS_PATH,
    transform=eval_transforms
    )

    print(f"Train dataset: {len(full_train_dataset)} images.")
    print(f"Test dataset: {len(test_dataset)} images.")

    # Train/Validation Split
    print("Splitting train data")
    targets = full_train_dataset.labels

    train_idx, val_idx = train_test_split(
        np.arange(len(targets)),
        test_size=0.2, # 20% for validation
        stratify=targets,
        random_state=RANDOM_SEED
    )

    train_subset = Subset(full_train_dataset, train_idx)
    val_subset = Subset(full_train_dataset, val_idx)

    # Weighted sampler for the training subset
    train_targets = np.array(targets)[train_idx]
    class_counts = np.bincount(train_targets, minlength=NUM_CLASSES)

    weights = 1.0 / class_counts #what if a class has no samples in the split

    sample_weights = np.array([weights[label] for label in train_targets])
    sampler = WeightedRandomSampler(sample_weights, len(sample_weights), replacement=True)

    print(f"Training subset size: {len(train_subset)}")
    print(f"Validation subset size: {len(val_subset)}")


    print("DataLoaders")
    num_workers = 2

    train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, sampler=sampler, num_workers=num_workers, pin_memory=True)
    val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True)

    # creating model instance
    print(f"Model with {BACKBONE_NAME} backbone")
    model = AttentionMILModel(
        num_classes=NUM_CLASSES,
        backbone_name=BACKBONE_NAME,
        pretrained=PRETRAINED,
        dropout=DROPOUT_RATE).to(device)


    class_weights_tensor = torch.tensor(CLASS_WEIGHTS, device=device, dtype=torch.float)
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
    print(f"Using CrossEntropyLoss with the weights: {CLASS_WEIGHTS}")


    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
    # scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.1)

    # train model
    trained_model, history = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        criterion=criterion,
        optimizer=optimizer,
        num_epochs=NUM_EPOCHS,
        device=device,
        save_dir=SAVE_MODEL_DIR,
        model_name='sbam5.pth',
        patience=PATIENCE
    )

    # Evaluat on Test Set
    print("\nEvaluating on test set")
    trained_model.to(device)
    test_metrics, all_labels, all_preds = evaluate_model(trained_model, test_loader, criterion, device)
    cmatrix = confusion_matrix(all_labels, all_preds)

    print("\nTest Set Evaluation Metrics")
    print(f"Loss: {test_metrics['loss']:.4f}")
    print(f"Accuracy: {test_metrics['accuracy']:.4f}")
    print(f"Precision: {test_metrics['precision']:.4f}")
    print(f"Recall: {test_metrics['recall']:.4f}")
    print(f"F1 Score: {test_metrics['f1']:.4f}")
    print("Confusion Matrix:")
    print(cmatrix)
    print("")

    print("\nEvaluation per class")
    print(classification_report(all_labels, all_preds, target_names=["Normal", "Benign", "Malignant"]))


    # --- Plotting ---
    print("\nPlotting results")
    plot_training_history(history['train_loss'], history['train_acc'],
                          history['val_loss'], history['val_acc'])

    #Confusion matrix
    plot_confusion_matrix(all_labels, all_preds, class_names=CLASS_NAMES)

    print("\nDONEEEEE.")
# Out:
# Using device: cuda
# Loading the datasets
# Train dataset: 1133 images.
# Test dataset: 122 images.
# Splitting train data
# Training subset size: 906
# Validation subset size: 227
# DataLoaders
# Model with vgg16 backbone
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:02<00:00, 202MB/s]
# Using CrossEntropyLoss with the weights: [0.8, 0.6, 3.0]
# Start Training model
# Epoch 1/50 | Train Loss: 1.0962, Acc: 0.3675 | Val Loss: 1.0659, Acc: 0.5154
# Model saved to /content/drive/MyDrive/GBCUD/sbam5.pth
# Epoch 2/50 | Train Loss: 0.8935, Acc: 0.5508 | Val Loss: 0.9125, Acc: 0.5551
# Model saved to /content/drive/MyDrive/GBCUD/sbam5.pth
# Epoch 3/50 | Train Loss: 0.7024, Acc: 0.6843 | Val Loss: 0.9463, Acc: 0.5815
# Validation loss did not improve for 1 epochs :(
# Epoch 4/50 | Train Loss: 0.5843, Acc: 0.7826 | Val Loss: 0.6177, Acc: 0.7269
# Model saved to /content/drive/MyDrive/GBCUD/sbam5.pth
# Epoch 5/50 | Train Loss: 0.4936, Acc: 0.8179 | Val Loss: 0.6050, Acc: 0.7533
# Model saved to /content/drive/MyDrive/GBCUD/sbam5.pth
# Epoch 6/50 | Train Loss: 0.4753, Acc: 0.8212 | Val Loss: 0.6716, Acc: 0.7181
# Validation loss did not improve for 1 epochs :(
# Epoch 7/50 | Train Loss: 0.3920, Acc: 0.8466 | Val Loss: 0.5958, Acc: 0.7313
# Model saved to /content/drive/MyDrive/GBCUD/sbam5.pth
# Epoch 8/50 | Train Loss: 0.3900, Acc: 0.8532 | Val Loss: 0.5884, Acc: 0.7930
# Model saved to /content/drive/MyDrive/GBCUD/sbam5.pth
# Epoch 9/50 | Train Loss: 0.2917, Acc: 0.8962 | Val Loss: 0.5866, Acc: 0.7885
# Model saved to /content/drive/MyDrive/GBCUD/sbam5.pth
# Epoch 10/50 | Train Loss: 0.2600, Acc: 0.9128 | Val Loss: 0.5487, Acc: 0.8326
# Model saved to /content/drive/MyDrive/GBCUD/sbam5.pth
# Epoch 11/50 | Train Loss: 0.2115, Acc: 0.9260 | Val Loss: 0.5004, Acc: 0.8062
# Model saved to /content/drive/MyDrive/GBCUD/sbam5.pth
# Epoch 12/50 | Train Loss: 0.2346, Acc: 0.9150 | Val Loss: 0.4461, Acc: 0.8414
# Model saved to /content/drive/MyDrive/GBCUD/sbam5.pth
# Epoch 13/50 | Train Loss: 0.2159, Acc: 0.9272 | Val Loss: 0.5328, Acc: 0.8150
# Validation loss did not improve for 1 epochs :(
# Epoch 14/50 | Train Loss: 0.2124, Acc: 0.9227 | Val Loss: 0.4338, Acc: 0.8414
# Model saved to /content/drive/MyDrive/GBCUD/sbam5.pth
# Epoch 15/50 | Train Loss: 0.1375, Acc: 0.9459 | Val Loss: 0.4472, Acc: 0.8282
# Validation loss did not improve for 1 epochs :(
# Epoch 16/50 | Train Loss: 0.1395, Acc: 0.9558 | Val Loss: 0.5317, Acc: 0.8326
# Validation loss did not improve for 2 epochs :(
# Epoch 17/50 | Train Loss: 0.1024, Acc: 0.9724 | Val Loss: 0.7820, Acc: 0.8062
# Validation loss did not improve for 3 epochs :(
# Epoch 18/50 | Train Loss: 0.1155, Acc: 0.9570 | Val Loss: 0.5961, Acc: 0.8502
# Validation loss did not improve for 4 epochs :(
# Epoch 19/50 | Train Loss: 0.0893, Acc: 0.9647 | Val Loss: 0.5285, Acc: 0.8414
# Validation loss did not improve for 5 epochs :(
# Epoch 20/50 | Train Loss: 0.0626, Acc: 0.9812 | Val Loss: 0.6141, Acc: 0.8326
# Validation loss did not improve for 6 epochs :(
# Epoch 21/50 | Train Loss: 0.0847, Acc: 0.9713 | Val Loss: 0.5571, Acc: 0.8194
# Validation loss did not improve for 7 epochs :(
# Epoch 22/50 | Train Loss: 0.0900, Acc: 0.9768 | Val Loss: 0.6138, Acc: 0.8282
# Validation loss did not improve for 8 epochs :(
# Epoch 23/50 | Train Loss: 0.0928, Acc: 0.9702 | Val Loss: 0.5884, Acc: 0.8106
# Validation loss did not improve for 9 epochs :(
# Epoch 24/50 | Train Loss: 0.1008, Acc: 0.9636 | Val Loss: 0.5237, Acc: 0.8502
# Validation loss did not improve for 10 epochs :(
# Early stopping at epoch 24
#
# Training donee.
# Loaded model weights.
#
# Evaluating on test set
#
# Test Set Evaluation Metrics
# Loss: 0.5752
# Accuracy: 0.8033
# Precision: 0.8095
# Recall: 0.8068
# F1 Score: 0.8079
# Confusion Matrix:
# [[26  4  1]
#  [ 4 39  6]
#  [ 1  8 33]]
#
#
# Evaluation per class
#               precision    recall  f1-score   support
#
#       Normal       0.84      0.84      0.84        31
#       Benign       0.76      0.80      0.78        49
#    Malignant       0.82      0.79      0.80        42
#
#     accuracy                           0.80       122
#    macro avg       0.81      0.81      0.81       122
# weighted avg       0.80      0.80      0.80       122
#
#
# Plotting results
# DONEEEEE.

# %% [markdown]
# for 100 epochs

# %%
BACKBONE_NAME = "vgg16"
PRETRAINED = "true"

# %%
if __name__ == "__main__":
    print(f"Using device: {device}")

    train_transforms = get_train_transforms(resize_dim=IMG_RESIZE, crop_dim=IMG_CROP_SIZE)
    eval_transforms = get_eval_transforms(img_dim=IMG_CROP_SIZE)

    print("Loading the datasets")

    full_train_dataset = ImageBagDataset(
        image_dir=TRAIN_IMGS_PATH,
        transform=train_transforms
    )

    test_dataset = ImageBagDataset(
    image_dir=TEST_IMGS_PATH,
    transform=eval_transforms
    )

    print(f"Train dataset: {len(full_train_dataset)} images.")
    print(f"Test dataset: {len(test_dataset)} images.")

    # Train/Validation Split
    print("Splitting train data")
    targets = full_train_dataset.labels

    train_idx, val_idx = train_test_split(
        np.arange(len(targets)),
        test_size=0.2, # 20% for validation
        stratify=targets,
        random_state=RANDOM_SEED
    )

    train_subset = Subset(full_train_dataset, train_idx)
    val_subset = Subset(full_train_dataset, val_idx)

    # Weighted sampler for the training subset
    train_targets = np.array(targets)[train_idx]
    class_counts = np.bincount(train_targets, minlength=NUM_CLASSES)

    weights = 1.0 / class_counts #what if a class has no samples in the split

    sample_weights = np.array([weights[label] for label in train_targets])
    sampler = WeightedRandomSampler(sample_weights, len(sample_weights), replacement=True)

    print(f"Training subset size: {len(train_subset)}")
    print(f"Validation subset size: {len(val_subset)}")


    print("DataLoaders")
    num_workers = 2

    train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, sampler=sampler, num_workers=num_workers, pin_memory=True)
    val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True)

    # creating model instance
    print(f"Model with {BACKBONE_NAME} backbone")
    model = AttentionMILModel(
        num_classes=NUM_CLASSES,
        backbone_name=BACKBONE_NAME,
        pretrained=PRETRAINED,
        dropout=DROPOUT_RATE).to(device)


    class_weights_tensor = torch.tensor(CLASS_WEIGHTS, device=device, dtype=torch.float)
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
    print(f"Using CrossEntropyLoss with the weights: {CLASS_WEIGHTS}")


    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
    # scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.1)

    # train model
    trained_model, history = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        criterion=criterion,
        optimizer=optimizer,
        num_epochs=100,
        device=device,
        save_dir=SAVE_MODEL_DIR,
        model_name='sbam5.pth',
        patience=PATIENCE
    )

    # Evaluat on Test Set
    print("\nEvaluating on test set")
    trained_model.to(device)
    test_metrics, all_labels, all_preds = evaluate_model(trained_model, test_loader, criterion, device)
    cmatrix = confusion_matrix(all_labels, all_preds)

    print("\nTest Set Evaluation Metrics")
    print(f"Loss: {test_metrics['loss']:.4f}")
    print(f"Accuracy: {test_metrics['accuracy']:.4f}")
    print(f"Precision: {test_metrics['precision']:.4f}")
    print(f"Recall: {test_metrics['recall']:.4f}")
    print(f"F1 Score: {test_metrics['f1']:.4f}")
    print("Confusion Matrix:")
    print(cmatrix)
    print("")

    print("\nEvaluation per class")
    print(classification_report(all_labels, all_preds, target_names=["Normal", "Benign", "Malignant"]))


    # --- Plotting ---
    print("\nPlotting results")
    plot_training_history(history['train_loss'], history['train_acc'],
                          history['val_loss'], history['val_acc'])

    #Confusion matrix
    plot_confusion_matrix(all_labels, all_preds, class_names=CLASS_NAMES)

    print("\nDONEEEEE.")
# Out:
# Using device: cuda
# Loading the datasets
# Train dataset: 1133 images.
# Test dataset: 122 images.
# Splitting train data
# Training subset size: 906
# Validation subset size: 227
# DataLoaders
# Model with vgg16 backbone
# Using CrossEntropyLoss with the weights: [0.8, 0.6, 3.0]
# Start Training model
# Epoch 1/100 | Train Loss: 1.0964, Acc: 0.3510 | Val Loss: 1.0798, Acc: 0.5683
# Epoch 2/100 | Train Loss: 0.9467, Acc: 0.5166 | Val Loss: 1.0264, Acc: 0.4714
# Epoch 3/100 | Train Loss: 0.6980, Acc: 0.6998 | Val Loss: 0.6808, Acc: 0.6916
# Epoch 4/100 | Train Loss: 0.5865, Acc: 0.7605 | Val Loss: 0.6960, Acc: 0.6916
# Epoch 5/100 | Train Loss: 0.5132, Acc: 0.7969 | Val Loss: 0.5309, Acc: 0.7665
# Epoch 6/100 | Train Loss: 0.4503, Acc: 0.8278 | Val Loss: 0.7050, Acc: 0.7577
# Epoch 7/100 | Train Loss: 0.3791, Acc: 0.8675 | Val Loss: 0.4631, Acc: 0.8062
# Epoch 8/100 | Train Loss: 0.3458, Acc: 0.8775 | Val Loss: 0.4896, Acc: 0.7885
# Epoch 9/100 | Train Loss: 0.2746, Acc: 0.9062 | Val Loss: 0.5185, Acc: 0.8106
# Epoch 10/100 | Train Loss: 0.2519, Acc: 0.9128 | Val Loss: 0.6521, Acc: 0.7974
# Epoch 11/100 | Train Loss: 0.2076, Acc: 0.9172 | Val Loss: 0.4878, Acc: 0.8326
# Epoch 95/100 | Train Loss: 0.0451, Acc: 0.9879 | Val Loss: 0.7312, Acc: 0.8546
# Epoch 96/100 | Train Loss: 0.0078, Acc: 0.9967 | Val Loss: 0.8501, Acc: 0.8590
# Epoch 97/100 | Train Loss: 0.0300, Acc: 0.9890 | Val Loss: 0.8429, Acc: 0.8326
# Epoch 98/100 | Train Loss: 0.0209, Acc: 0.9934 | Val Loss: 0.5853, Acc: 0.8722
# Epoch 99/100 | Train Loss: 0.0030, Acc: 1.0000 | Val Loss: 0.8007, Acc: 0.8722
# Epoch 100/100 | Train Loss: 0.0002, Acc: 1.0000 | Val Loss: 0.8473, Acc: 0.8678
#
# Training donee.
# Loaded model weights.
#
# Evaluating on test set
#
# Test Set Evaluation Metrics
# Loss: 1.4860
# Accuracy: 0.7131
# Precision: 0.7267
# Recall: 0.7285
# F1 Score: 0.7089
# Confusion Matrix:
# [[28  3  0]
#  [ 8 36  5]
#  [10  9 23]]
#
#
# Evaluation per class
#               precision    recall  f1-score   support
#
#       Normal       0.61      0.90      0.73        31
#       Benign       0.75      0.73      0.74        49
#    Malignant       0.82      0.55      0.66        42
#
#     accuracy                           0.71       122
#    macro avg       0.73      0.73      0.71       122
# weighted avg       0.74      0.71      0.71       122
#
#
# Plotting results
# DONEEEEE.

# %% [markdown]
# for 40 epochs

# %%
BACKBONE_NAME = "vgg16"
PRETRAINED = "true"

# %%
if __name__ == "__main__":
    print(f"Using device: {device}")

    train_transforms = get_train_transforms(resize_dim=IMG_RESIZE, crop_dim=IMG_CROP_SIZE)
    eval_transforms = get_eval_transforms(img_dim=IMG_CROP_SIZE)

    print("Loading the datasets")

    full_train_dataset = ImageBagDataset(
        image_dir=TRAIN_IMGS_PATH,
        transform=train_transforms
    )

    test_dataset = ImageBagDataset(
    image_dir=TEST_IMGS_PATH,
    transform=eval_transforms
    )

    print(f"Train dataset: {len(full_train_dataset)} images.")
    print(f"Test dataset: {len(test_dataset)} images.")

    # Train/Validation Split
    print("Splitting train data")
    targets = full_train_dataset.labels

    train_idx, val_idx = train_test_split(
        np.arange(len(targets)),
        test_size=0.2, # 20% for validation
        stratify=targets,
        random_state=RANDOM_SEED
    )

    train_subset = Subset(full_train_dataset, train_idx)
    val_subset = Subset(full_train_dataset, val_idx)

    # Weighted sampler for the training subset
    train_targets = np.array(targets)[train_idx]
    class_counts = np.bincount(train_targets, minlength=NUM_CLASSES)

    weights = 1.0 / class_counts #what if a class has no samples in the split

    sample_weights = np.array([weights[label] for label in train_targets])
    sampler = WeightedRandomSampler(sample_weights, len(sample_weights), replacement=True)

    print(f"Training subset size: {len(train_subset)}")
    print(f"Validation subset size: {len(val_subset)}")


    print("DataLoaders")
    num_workers = 2

    train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, sampler=sampler, num_workers=num_workers, pin_memory=True)
    val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True)

    # creating model instance
    print(f"Model with {BACKBONE_NAME} backbone")
    model = AttentionMILModel(
        num_classes=NUM_CLASSES,
        backbone_name=BACKBONE_NAME,
        pretrained=PRETRAINED,
        dropout=DROPOUT_RATE).to(device)


    class_weights_tensor = torch.tensor(CLASS_WEIGHTS, device=device, dtype=torch.float)
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
    print(f"Using CrossEntropyLoss with the weights: {CLASS_WEIGHTS}")


    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
    # scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.1)

    # train model
    trained_model, history = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        criterion=criterion,
        optimizer=optimizer,
        num_epochs=100,
        device=device,
        save_dir=SAVE_MODEL_DIR,
        model_name='sbam6.pth',
        patience=PATIENCE
    )

    # Evaluat on Test Set
    print("\nEvaluating on test set")
    trained_model.to(device)
    test_metrics, all_labels, all_preds = evaluate_model(trained_model, test_loader, criterion, device)
    cmatrix = confusion_matrix(all_labels, all_preds)

    print("\nTest Set Evaluation Metrics")
    print(f"Loss: {test_metrics['loss']:.4f}")
    print(f"Accuracy: {test_metrics['accuracy']:.4f}")
    print(f"Precision: {test_metrics['precision']:.4f}")
    print(f"Recall: {test_metrics['recall']:.4f}")
    print(f"F1 Score: {test_metrics['f1']:.4f}")
    print("Confusion Matrix:")
    print(cmatrix)
    print("")

    print("\nEvaluation per class")
    print(classification_report(all_labels, all_preds, target_names=["Normal", "Benign", "Malignant"]))


    # --- Plotting ---
    print("\nPlotting results")
    plot_training_history(history['train_loss'], history['train_acc'],
                          history['val_loss'], history['val_acc'])

    #Confusion matrix
    plot_confusion_matrix(all_labels, all_preds, class_names=CLASS_NAMES)

    print("\nDONEEEEE.")
# Out:
# Using device: cuda
# Loading the datasets
# Train dataset: 1133 images.
# Test dataset: 122 images.
# Splitting train data
# Training subset size: 906
# Validation subset size: 227
# DataLoaders
# Model with vgg16 backbone
# Using CrossEntropyLoss with the weights: [0.8, 0.6, 3.0]
# Start Training model
# Epoch 1/100 | Train Loss: 1.0937, Acc: 0.3808 | Val Loss: 1.0092, Acc: 0.4978
# Epoch 2/100 | Train Loss: 0.8799, Acc: 0.5795 | Val Loss: 0.7685, Acc: 0.6167
# Epoch 3/100 | Train Loss: 0.6915, Acc: 0.6932 | Val Loss: 0.6490, Acc: 0.7093
# Epoch 4/100 | Train Loss: 0.5257, Acc: 0.7914 | Val Loss: 0.6431, Acc: 0.7093
# Epoch 5/100 | Train Loss: 0.4783, Acc: 0.8124 | Val Loss: 0.6427, Acc: 0.7533
# Epoch 6/100 | Train Loss: 0.4589, Acc: 0.8300 | Val Loss: 0.6085, Acc: 0.7841
# Epoch 7/100 | Train Loss: 0.4043, Acc: 0.8466 | Val Loss: 0.5880, Acc: 0.7621
# Epoch 8/100 | Train Loss: 0.3101, Acc: 0.8819 | Val Loss: 0.6221, Acc: 0.7974
# Epoch 9/100 | Train Loss: 0.3072, Acc: 0.8808 | Val Loss: 0.7413, Acc: 0.7665
# Epoch 10/100 | Train Loss: 0.2581, Acc: 0.9139 | Val Loss: 0.4706, Acc: 0.8106
# Epoch 11/100 | Train Loss: 0.2351, Acc: 0.9205 | Val Loss: 0.5158, Acc: 0.8282
# Epoch 12/100 | Train Loss: 0.2121, Acc: 0.9238 | Val Loss: 0.4984, Acc: 0.8282
# Epoch 13/100 | Train Loss: 0.1664, Acc: 0.9514 | Val Loss: 0.5141, Acc: 0.8326
# Epoch 14/100 | Train Loss: 0.1804, Acc: 0.9448 | Val Loss: 0.5083, Acc: 0.8326
# Epoch 15/100 | Train Loss: 0.1489, Acc: 0.9514 | Val Loss: 0.5672, Acc: 0.8370
# Epoch 16/100 | Train Loss: 0.1625, Acc: 0.9415 | Val Loss: 0.4228, Acc: 0.8590
# Epoch 17/100 | Train Loss: 0.1251, Acc: 0.9592 | Val Loss: 0.5813, Acc: 0.8194
#
# Training donee.
# Loaded model weights.
#
# Evaluating on test set
#
# Test Set Evaluation Metrics
# Loss: 1.8128
# Accuracy: 0.6639
# Precision: 0.7075
# Recall: 0.6815
# F1 Score: 0.6648
# Confusion Matrix:
# [[27  4  0]
#  [14 33  2]
#  [ 5 16 21]]
#
#
# Evaluation per class
#               precision    recall  f1-score   support
#
#       Normal       0.59      0.87      0.70        31
#       Benign       0.62      0.67      0.65        49
#    Malignant       0.91      0.50      0.65        42
#
#     accuracy                           0.66       122
#    macro avg       0.71      0.68      0.66       122
# weighted avg       0.71      0.66      0.66       122
#
#
# Plotting results
# DONEEEEE.

# %% [markdown]
# # Final

# %%
BACKBONE_NAME = "vgg16"
PRETRAINED = "true"

# %%
if __name__ == "__main__":
    print(f"Using device: {device}")

    train_transforms = get_train_transforms(resize_dim=IMG_RESIZE, crop_dim=IMG_CROP_SIZE)
    eval_transforms = get_eval_transforms(img_dim=IMG_CROP_SIZE)

    print("Loading the datasets")

    full_train_dataset = ImageBagDataset(
        image_dir=TRAIN_IMGS_PATH,
        transform=train_transforms
    )

    test_dataset = ImageBagDataset(
    image_dir=TEST_IMGS_PATH,
    transform=eval_transforms
    )

    print(f"Train dataset: {len(full_train_dataset)} images.")
    print(f"Test dataset: {len(test_dataset)} images.")

    # Train/Validation Split
    print("Splitting train data")
    targets = full_train_dataset.labels

    train_idx, val_idx = train_test_split(
        np.arange(len(targets)),
        test_size=0.2, # 20% for validation
        stratify=targets,
        random_state=RANDOM_SEED
    )

    train_subset = Subset(full_train_dataset, train_idx)
    val_subset = Subset(full_train_dataset, val_idx)

    # Weighted sampler for the training subset
    train_targets = np.array(targets)[train_idx]
    class_counts = np.bincount(train_targets, minlength=NUM_CLASSES)

    weights = 1.0 / class_counts #what if a class has no samples in the split

    sample_weights = np.array([weights[label] for label in train_targets])
    sampler = WeightedRandomSampler(sample_weights, len(sample_weights), replacement=True)

    print(f"Training subset size: {len(train_subset)}")
    print(f"Validation subset size: {len(val_subset)}")


    print("DataLoaders")
    num_workers = 2

    train_loader = DataLoader(train_subset, batch_size=BATCH_SIZE, sampler=sampler, num_workers=num_workers, pin_memory=True)
    val_loader = DataLoader(val_subset, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=num_workers, pin_memory=True)

    # creating model instance
    print(f"Model with {BACKBONE_NAME} backbone")
    model = AttentionMILModel(
        num_classes=NUM_CLASSES,
        backbone_name=BACKBONE_NAME,
        pretrained=PRETRAINED,
        dropout=DROPOUT_RATE).to(device)


    class_weights_tensor = torch.tensor(CLASS_WEIGHTS, device=device, dtype=torch.float)
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor)
    print(f"Using CrossEntropyLoss with the weights: {CLASS_WEIGHTS}")


    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE, weight_decay=WEIGHT_DECAY)
    # scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=5, factor=0.1)

    # train model
    trained_model, history = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        criterion=criterion,
        optimizer=optimizer,
        num_epochs=NUM_EPOCHS,
        device=device,
        save_dir=SAVE_MODEL_DIR,
        model_name='sbam7.pth',
        patience=PATIENCE
    )

    # Evaluat on Test Set
    print("\nEvaluating on test set")
    trained_model.to(device)
    test_metrics, all_labels, all_preds = evaluate_model(trained_model, test_loader, criterion, device)
    cmatrix = confusion_matrix(all_labels, all_preds)

    print("\nTest Set Evaluation Metrics")
    print(f"Loss: {test_metrics['loss']:.4f}")
    print(f"Accuracy: {test_metrics['accuracy']:.4f}")
    print(f"Precision: {test_metrics['precision']:.4f}")
    print(f"Recall: {test_metrics['recall']:.4f}")
    print(f"F1 Score: {test_metrics['f1']:.4f}")
    print(f"AUC: {test_metrics['auc']:.4f}")
    print("Confusion Matrix:")
    print(cmatrix)
    print("")

    print("\nEvaluation per class")
    print(classification_report(all_labels, all_preds, target_names=["Normal", "Benign", "Malignant"]))


    # --- Plotting ---
    print("\nPlotting results")
    plot_training_history(history['train_loss'], history['train_acc'],
                          history['val_loss'], history['val_acc'])

    #Confusion matrix
    plot_confusion_matrix(all_labels, all_preds, class_names=CLASS_NAMES)

    print("\nDONEEEEE.")
# Out:
# Using device: cuda
# Loading the datasets
# Train dataset: 1133 images.
# Test dataset: 122 images.
# Splitting train data
# Training subset size: 906
# Validation subset size: 227
# DataLoaders
# Model with vgg16 backbone
# Using CrossEntropyLoss with the weights: [0.8, 0.6, 3.0]
# Start Training model
# Epoch 1/50 | Train Loss: 1.0225, Acc: 0.4349 | Val Loss: 0.9171, Acc: 0.4846
# Model saved to /content/drive/MyDrive/GBCUD/sbam7.pth
# Epoch 2/50 | Train Loss: 0.8289, Acc: 0.6115 | Val Loss: 0.8102, Acc: 0.6344
# Model saved to /content/drive/MyDrive/GBCUD/sbam7.pth
# Epoch 3/50 | Train Loss: 0.7124, Acc: 0.6744 | Val Loss: 0.7961, Acc: 0.6476
# Model saved to /content/drive/MyDrive/GBCUD/sbam7.pth
# Epoch 4/50 | Train Loss: 0.6094, Acc: 0.7152 | Val Loss: 0.7609, Acc: 0.6608
# Model saved to /content/drive/MyDrive/GBCUD/sbam7.pth
# Epoch 5/50 | Train Loss: 0.5784, Acc: 0.7660 | Val Loss: 0.6989, Acc: 0.7313
# Model saved to /content/drive/MyDrive/GBCUD/sbam7.pth
# Epoch 6/50 | Train Loss: 0.4769, Acc: 0.8179 | Val Loss: 0.5732, Acc: 0.7709
# Model saved to /content/drive/MyDrive/GBCUD/sbam7.pth
# Epoch 7/50 | Train Loss: 0.4401, Acc: 0.8179 | Val Loss: 0.5284, Acc: 0.7885
# Model saved to /content/drive/MyDrive/GBCUD/sbam7.pth
# Epoch 8/50 | Train Loss: 0.3534, Acc: 0.8775 | Val Loss: 0.6349, Acc: 0.7930
# Validation loss did not improve for 1 epochs :(
# Epoch 9/50 | Train Loss: 0.3506, Acc: 0.8742 | Val Loss: 0.4784, Acc: 0.8062
# Model saved to /content/drive/MyDrive/GBCUD/sbam7.pth
# Epoch 10/50 | Train Loss: 0.2840, Acc: 0.8940 | Val Loss: 0.4970, Acc: 0.8194
# Validation loss did not improve for 1 epochs :(
# Epoch 11/50 | Train Loss: 0.2588, Acc: 0.8996 | Val Loss: 0.4516, Acc: 0.8238
# Model saved to /content/drive/MyDrive/GBCUD/sbam7.pth
# Epoch 12/50 | Train Loss: 0.2423, Acc: 0.9161 | Val Loss: 0.6028, Acc: 0.8194
# Validation loss did not improve for 1 epochs :(
# Epoch 13/50 | Train Loss: 0.1866, Acc: 0.9327 | Val Loss: 0.5313, Acc: 0.8018
# Validation loss did not improve for 2 epochs :(
# Epoch 14/50 | Train Loss: 0.1719, Acc: 0.9426 | Val Loss: 0.4673, Acc: 0.8458
# Validation loss did not improve for 3 epochs :(
# Epoch 15/50 | Train Loss: 0.1405, Acc: 0.9459 | Val Loss: 0.7977, Acc: 0.8282
# Validation loss did not improve for 4 epochs :(
# Epoch 16/50 | Train Loss: 0.1393, Acc: 0.9492 | Val Loss: 0.6071, Acc: 0.8282
# Validation loss did not improve for 5 epochs :(
# Epoch 17/50 | Train Loss: 0.1331, Acc: 0.9547 | Val Loss: 0.7710, Acc: 0.8062
# Validation loss did not improve for 6 epochs :(
# Epoch 18/50 | Train Loss: 0.1318, Acc: 0.9558 | Val Loss: 0.6385, Acc: 0.8194
# Validation loss did not improve for 7 epochs :(
# Epoch 19/50 | Train Loss: 0.0839, Acc: 0.9691 | Val Loss: 0.4665, Acc: 0.8458
# Validation loss did not improve for 8 epochs :(
# Epoch 20/50 | Train Loss: 0.1123, Acc: 0.9647 | Val Loss: 0.4383, Acc: 0.8502
# Model saved to /content/drive/MyDrive/GBCUD/sbam7.pth
# Epoch 21/50 | Train Loss: 0.0684, Acc: 0.9735 | Val Loss: 0.4289, Acc: 0.8722
# Model saved to /content/drive/MyDrive/GBCUD/sbam7.pth
# Epoch 22/50 | Train Loss: 0.0839, Acc: 0.9713 | Val Loss: 0.4896, Acc: 0.8767
# Validation loss did not improve for 1 epochs :(
# Epoch 23/50 | Train Loss: 0.0935, Acc: 0.9713 | Val Loss: 0.5494, Acc: 0.8370
# Validation loss did not improve for 2 epochs :(
# Epoch 24/50 | Train Loss: 0.0648, Acc: 0.9779 | Val Loss: 0.5820, Acc: 0.8590
# Validation loss did not improve for 3 epochs :(
# Epoch 25/50 | Train Loss: 0.0814, Acc: 0.9691 | Val Loss: 0.4577, Acc: 0.8767
# Validation loss did not improve for 4 epochs :(
# Epoch 26/50 | Train Loss: 0.0633, Acc: 0.9779 | Val Loss: 0.5616, Acc: 0.8590
# Validation loss did not improve for 5 epochs :(
# Epoch 27/50 | Train Loss: 0.0271, Acc: 0.9923 | Val Loss: 1.3356, Acc: 0.6960
# Validation loss did not improve for 6 epochs :(
# Epoch 28/50 | Train Loss: 0.0859, Acc: 0.9746 | Val Loss: 0.3939, Acc: 0.8722
# Model saved to /content/drive/MyDrive/GBCUD/sbam7.pth
# Epoch 29/50 | Train Loss: 0.0468, Acc: 0.9845 | Val Loss: 0.9080, Acc: 0.8282
# Validation loss did not improve for 1 epochs :(
# Epoch 30/50 | Train Loss: 0.0367, Acc: 0.9912 | Val Loss: 0.5367, Acc: 0.8811
# Validation loss did not improve for 2 epochs :(
# Epoch 31/50 | Train Loss: 0.0768, Acc: 0.9812 | Val Loss: 0.5221, Acc: 0.8855
# Validation loss did not improve for 3 epochs :(
# Epoch 32/50 | Train Loss: 0.0541, Acc: 0.9868 | Val Loss: 0.6033, Acc: 0.8458
# Validation loss did not improve for 4 epochs :(
# Epoch 33/50 | Train Loss: 0.0551, Acc: 0.9823 | Val Loss: 1.2069, Acc: 0.8018
# Validation loss did not improve for 5 epochs :(
# Epoch 34/50 | Train Loss: 0.0770, Acc: 0.9779 | Val Loss: 0.4542, Acc: 0.8767
# Validation loss did not improve for 6 epochs :(
# Epoch 35/50 | Train Loss: 0.0322, Acc: 0.9879 | Val Loss: 0.7038, Acc: 0.8678
# Validation loss did not improve for 7 epochs :(
# Epoch 36/50 | Train Loss: 0.0509, Acc: 0.9845 | Val Loss: 0.9415, Acc: 0.8326
# Validation loss did not improve for 8 epochs :(
# Epoch 37/50 | Train Loss: 0.0597, Acc: 0.9834 | Val Loss: 1.0690, Acc: 0.7665
# Validation loss did not improve for 9 epochs :(
# Epoch 38/50 | Train Loss: 0.0388, Acc: 0.9879 | Val Loss: 0.5696, Acc: 0.8634
# Validation loss did not improve for 10 epochs :(
# Early stopping at epoch 38
#
# Training donee.
# Loaded model weights.
#
# Evaluating on test set
#
# Test Set Evaluation Metrics
# Loss: 1.4704
# Accuracy: 0.6311
# Precision: 0.7846
# Recall: 0.6322
# F1 Score: 0.5749
# AUC: 0.5000
# Confusion Matrix:
# [[26  5  0]
#  [ 3 46  0]
#  [ 3 34  5]]
#
#
# Evaluation per class
#               precision    recall  f1-score   support
#
#       Normal       0.81      0.84      0.83        31
#       Benign       0.54      0.94      0.69        49
#    Malignant       1.00      0.12      0.21        42
#
#     accuracy                           0.63       122
#    macro avg       0.78      0.63      0.57       122
# weighted avg       0.77      0.63      0.56       122
#
#
# Plotting results
# DONEEEEE.
